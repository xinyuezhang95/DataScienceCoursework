# %%
print('''
*******************************************************************************
          |                   |                  |                     |
 _________|________________.=""_;=.______________|_____________________|_______
|                   |  ,-"_,=""     `"=.|                  |
|___________________|__"=._o`"-._        `"=.______________|___________________
          |                `"=._o`"=._      _`"=._                     |
 _________|_____________________:=._o "=._."_.-="'"=.__________________|_______
|                   |    __.--" , ; `"=._o." ,-"""-._ ".   |
|___________________|_._"  ,. .` ` `` ,  `"-._"-._   ". '__|___________________
          |           |o`"=._` , "` `; .". ,  "-._"-._; ;              |
 _________|___________| ;`-.o`"=._; ." ` '`."\` . "-._ /_______________|_______
|                   | |o;    `"-.o`"=._``  '` " ,__.--o;   |
|___________________|_| ;     (#) `-.o `"=.`_.--"_o.-; ;___|___________________
____/______/______/___|o;._    "      `".o|o_.--"    ;o;____/______/______/____
/______/______/______/_"=._o--._        ; | ;        ; ;/______/______/______/_
____/______/______/______/__"=._o--._   ;o|o;     _._;o;____/______/______/____
/______/______/______/______/____"=._o._; | ;_.--"o.--"_/______/______/______/_
____/______/______/______/______/_____"=.o|o_.--""___/______/______/______/____
/______/______/______/______/______/______/______/______/______/______/________
*******************************************************************************
''')

print("Welcome to Treasure Island")
print("Your mission is to find the treasure!")

flower = """
                                          ....
                                       ,;;'''';;,                    ,;;;;,
                             ,        ;;'      `;;,               .,;;;'   ;
                          ,;;;       ;;          `;;,';;;,.     ,%;;'     '
                        ,;;,;;       ;;         ,;`;;;, `;::.  %%;'
                       ;;;,;;;       `'       ,;;; ;;,;;, `::,%%;'
                       ;;;,;;;,          .,%%%%%'% ;;;;,;;   %;;;
             ,%,.      `;;;,;;;,    .,%%%%%%%%%'%; ;;;;;,;;  %;;;
            ;,`%%%%%%%%%%`;;,;;'%%%%%%%%%%%%%'%%'  `;;;;;,;, %;;;
            ;;;,`%%%%%%%%%%%,; ..`%%%%%%%%;'%%%'    `;;;;,;; %%;;
             `;;;;;,`%%%%%,;;/, .. `''''',%%%%%      `;;;;;; %%;;,
                `;;;;;;;,;;/////,.    ,;%%%%%%%        `;;;;,`%%;;
                       ;;;/%%%%,%///;;;';%%%%%%,          `;;;%%;;,
                      ;;;/%%%,%%%%%/;;;';;'%%%%%,             `%%;;
                     .;;/%%,%%%%%//;;'  ;;;'%%%%%,             %%;;,
                     ;;//%,%%%%//;;;'   `;;;;'%%%%             `%;;;
                     ;;//%,%//;;;;'      `;;;;'%%%              %;;;,
                     `;;//,/;;;'          `;;;'%%'              `%;;;
                       `;;;;'               `;'%'                `;;;;
                                              '      .,,,.        `;;;;
                                                  ,;;;;;;;;;;,     `;;;;
                                                 ;;;'    ;;;,;;,    `;;;;
                                                 ;;;      ;;;;,;;.   `;;;;
                                                  `;;      ;;;;;,;;   ;;;;
                                                    `'      `;;;;,;;  ;;;;
                                                               `;;,;, ;;;;
                                                                  ;;, ;;;;
                                                                    ';;;;;
                                                                     ;;;;;
                                                                    .;;;;'
                                                                   .;;;;'
                                                                  ;;;;;'
                                                                 ,;;;;'
"""

panda = '''
$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
$$$$$$$$$$$$**$$$$$$$$$**$$$$$$$$$$$$$$$$$$$$
$$$$$$$$$$"   ^$$$$$$F    *$$$$$$$$$$$$$$$$$$
$$$$$$$$$     z$$$$$$L    ^$$$$$$$$$$$$$$$$$$
$$$$$$$$$    e$$$$$$$$$e  J$$$$$$$$$$$$$$$$$$
$$$$$$$$$eee$$$$$$$$$$$$$e$$$$$$$$$$$$$$$$$$$
$$$$$$$$b$$$$$$$$$$$$$$$$$$*$$$$$$$$$$$$$$$$$
$$$$$$$)$$$$P"e^$$$F$r*$$$$F"$$$$$$$$$$$$$$$$
$$$$$$$d$$$$  "z$$$$"  $$$$%  $3$$$$$$$$$$$$$
$$$$*"""*$$$  .$$$$$$ z$$$*   ^$e*$$$$$$$$$$$
$$$"     *$$ee$$$$$$$$$$*"     $$$C$$$$$$$$$$
$$$.      "***$$"*"$$""        $$$$e*$$$$$$$$
$$$b          "$b.$$"          $$$$$b"$$$$$$$
$$$$$c.         """            $$$$$$$^$$$$$$
$$$$$$$e..                     $$$$$$$$^$$$$$
$$$$$$$$$$$$eeee..            J$$$$$$$$b"$$$$
$$$$$$$$$$$$$$$$$$r          z$$$$$$$$$$r$$$$
$$$$$$$$$$$$$$$$$$"         z$$$$$**$$$$$^$$$
$$$$$$$$$$$$$$$*"          z$$$P"   ^*$$$ $$$
$$$$$$$$$$$$*"           .d$$$$       $$$ $$$
$$$$$$$$$$$"           .e$$$$$F       3$$ $$$
$$$$$$$$$$$.         .d$$$$$$$         $PJ$$$
$$$$$$$$$$$$eeeeeeed$*""""**""         $\$$$$
$$$$$$$$$$$$$$$$$$$$$                  $d$$$$
$$$$$$$$$$$$$$$$$$$$$.                 $$$$$$
$$$$$$$$$$$$$$$$$$$$$$e.              d$$$$$$
$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$eeeeeee$$$$$$$$
'''

wizard = '''
         ,/   *
      _,'/_   |
      `(")' ,'/
   _ _,-H-./ /
   \_\_\.   /
     )" |  (
  __/   H   \__
  \    /|\    /
   `--'|||`--'
      ==^==
'''

treasure = '''
                            _.--.
                        _.-'_:-'||
                    _.-'_.-::::'||
               _.-:'_.-::::::'  ||
             .'`-.-:::::::'     ||
            /.'`;|:::::::'      ||_
           ||   ||::::::'     _.;._'-._
           ||   ||:::::'  _.-!oo @.!-._'-.
           \'.  ||:::::.-!()oo @!()@.-'_.|
            '.'-;|:.-'.&$@.& ()$%-'o.'\ ||
              `>'-.!@%()@'@_%-'_.-o _.|'||
               ||-._'-.@.-'_.-' _.-o  |'||
               ||=[ '-._.-\ /.-'    o |'||
               || '-.]=|| |'|      o  |'||
               ||      || |'|        _| ';
               ||      || |'|    _.-'_.-'
               |'-._   || |'|_.-'_.-'
               '-._'-.|| |' `_.-'
                    '-.||_/.-'
'''

apple = '''
             .:'
         __ :'__
      .'`  `-'  ``.
     :             :
     :             :
      :           :
       `.__.-.__.'

'''

dog = '''         
            |\\
   \`-. _.._| \\
    |_,'  __`. \\
    (.\ _/.| _  |
   ,'      __ \ |
 ,'     __/||\  |
(    ,/|||||/  |
   `-'_----    /
      /`-._.-'/
      `-.__.-' 
'''

direction = input("You are at a crossroad. Do you want to turn left or right?\n")

if direction.lower() == 'right':
    print("You meet a huge Piranha Plant. You are dead.")
    print(flower)
elif direction.lower() == 'left':
    print(panda)
    color = input("You meet a cute little panda. He shows you three doors with different colors: red, yellow, and green, and asks you to pick one. Which one do you want to pick?\n")
    if color.lower() == 'yellow':
        print(treasure)
        print("Congratulations! You find the treasure!")
    elif color.lower() == 'red':
        print(apple)
        print("An apple hits your head from above. You are dead.")
    elif color.lower() == 'green':
        print('\n')
        print(dog)
        print("You meet a ferocious dog. You are dead.")
    else:
        print(wizard)
        print("A wizard jumps out of nowhere and waves at you. You are dead.")
else:
    print(wizard)
    print("A wizard jumps out of nowhere and waves at you. You are dead.")
# Out:
# *******************************************************************************
#           |                   |                  |                     |
#  _________|________________.=""_;=.______________|_____________________|_______
# |                   |  ,-"_,=""     `"=.|                  |
# |___________________|__"=._o`"-._        `"=.______________|___________________
#           |                `"=._o`"=._      _`"=._                     |
#  _________|_____________________:=._o "=._."_.-="'"=.__________________|_______
# |                   |    __.--" , ; `"=._o." ,-"""-._ ".   |
# |___________________|_._"  ,. .` ` `` ,  `"-._"-._   ". '__|___________________
#           |           |o`"=._` , "` `; .". ,  "-._"-._; ;              |
#  _________|___________| ;`-.o`"=._; ." ` '`."\` . "-._ /_______________|_______
# |                   | |o;    `"-.o`"=._``  '` " ,__.--o;   |
# |___________________|_| ;     (#) `-.o `"=.`_.--"_o.-; ;___|___________________
# ...
